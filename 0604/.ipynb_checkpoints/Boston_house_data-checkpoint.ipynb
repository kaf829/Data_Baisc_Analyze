# %%
from sklearn.model_selection import train_test_split
import pandas as pd

df = pd.read_csv("boston_house.csv")
df.head()
# Out:
#     AGE       B     RM     CRIM     DIS  INDUS  LSTAT    NOX  PTRATIO  RAD  \
# 0  65.2  396.90  6.575  0.00632  4.0900   2.31   4.98  0.538     15.3    1
# 1  78.9  396.90  6.421  0.02731  4.9671   7.07   9.14  0.469     17.8    2
# 2  61.1  392.83  7.185  0.02729  4.9671   7.07   4.03  0.469     17.8    2
# 3  45.8  394.63  6.998  0.03237  6.0622   2.18   2.94  0.458     18.7    3
# 4  54.2  396.90  7.147  0.06905  6.0622   2.18   5.33  0.458     18.7    3
#
#      ZN  TAX  CHAS  Target
# 0  18.0  296     0    24.0
# 1   0.0  242     0    21.6
# 2   0.0  242     0    34.7
# 3   0.0  222     0    33.4
# 4   0.0  222     0    36.2

# %%
dfx = df.drop(["Target"], axis = 1) #target 삭제
dfx.head()
# Out:
#     AGE       B     RM     CRIM     DIS  INDUS  LSTAT    NOX  PTRATIO  RAD  \
# 0  65.2  396.90  6.575  0.00632  4.0900   2.31   4.98  0.538     15.3    1
# 1  78.9  396.90  6.421  0.02731  4.9671   7.07   9.14  0.469     17.8    2
# 2  61.1  392.83  7.185  0.02729  4.9671   7.07   4.03  0.469     17.8    2
# 3  45.8  394.63  6.998  0.03237  6.0622   2.18   2.94  0.458     18.7    3
# 4  54.2  396.90  7.147  0.06905  6.0622   2.18   5.33  0.458     18.7    3
#
#      ZN  TAX  CHAS
# 0  18.0  296     0
# 1   0.0  242     0
# 2   0.0  242     0
# 3   0.0  222     0
# 4   0.0  222     0

# %%
dfy = df["Target"]
#dfy

# %%
X_train, X_test, y_train, y_test = train_test_split(dfx, dfy, test_size = 0.2 , random_state = 42)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((404, 13), (102, 13), (404,), (102,))

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
pred = model.predict(X_train)

# %%
from sklearn.metrics import mean_squeared_error

mse_test = mean_squared_error(y_test, pred)
mse_test
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 from sklearn.metrics import mean_squeared_error
#       3 mse_test = mean_squared_error(y_test, pred)
#       4 mse_test
#
# ImportError: cannot import name 'mean_squeared_error' from 'sklearn.metrics' (C:\Users\MINJUN\Documents\GitHub\Data_Baisc_Analyze\Data_Baisc_Analyze\.venv\Lib\site-packages\sklearn\metrics\__init__.py)

# %%
score = model.score(X_test, y_test)
print("정확도", score)
cofficient = model.coef_
intercept = model.intercept_

print("계수" , cofficient)
print("절편:", intercept)
