# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
import warnings
warnings.filterwarnings('ignore')

# %%
mushrooms = pd.read_csv("./mushroom.csv")

# %%
mushrooms.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
le = LabelEncoder()
for col in df.columns:
    df[col] = le.fit_transform(df[col])

X = df.drop('class', axis=1)
y = df['class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

forest = RandomForestClassifier(random_state=42)
forest.fit(X_test,y_test)

feature_importance_values = forest.feature_importances_
feature_importance = pd.Series(feature_importance_values, index=X_train.columns)
print(forest.score(X_test,y_test))
feature = feature_importance.sort_values(ascending=False)

plt.rcParams['axes.unicode_minus'] = False
plt.rc('font', family='Malgun Gothic')
plt.figure(figsize=(8, 5))
sns.barplot(x=feature, y=feature.index)
plt.title("랜덤포레스트 중요 특성")
plt.xlabel("중요도")
plt.ylabel("특성 이름")
plt.tight_layout()
plt.show()
# Out:
# 1.0

# %%
param_grid = {
    'n_estimators': [50,70,90],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [None,1,2],
    'min_samples_leaf': [None, 1, 2],
    'max_features': ['sqrt'],
    'bootstrap': [True, False]
}

hyperParmeter_search = GridSearchCV(forest, param_grid,
                                    cv=5, scoring='accuracy', n_jobs=-1, verbose=1)
hyperParmeter_search.fit(X_train, y_train)

best_model = hyperParmeter_search.best_estimator_

train_acc = best_model.score(X_train, y_train)
test_acc = best_model.score(X_test, y_test)

print("최적 하이퍼파라미터:", hyperParmeter_search.best_params_)
print("훈련 정확도:", train_acc )
print("테스트 정확도:",test_acc)
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# 최적 하이퍼파라미터: {'bootstrap': True, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
# 훈련 정확도: 1.0
# 테스트 정확도: 1.0

# %%
y_pred = best_model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1257
#            1       1.00      1.00      1.00      1181
#
#     accuracy                           1.00      2438
#    macro avg       1.00      1.00      1.00      2438
# weighted avg       1.00      1.00      1.00      2438
